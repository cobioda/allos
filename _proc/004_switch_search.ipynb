# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(SwitchSearch)
# Out:
# ---
#
# [source](https://github.com/cobioda/allos/blob/main/allos/switch_search.py#L36){target="_blank" style="float:right; font-size:smaller"}
#
# ### SwitchSearch
#
# >      SwitchSearch (anndata:anndata._core.anndata.AnnData,
# >                    cell_types:pandas.core.frame.DataFrame, palette='ghibli')
#
# *An annotated data matrix.
#
# .. figure:: ../_static/img/anndata_schema.svg
#    :width: 260px
#    :align: right
#    :class: dark-light
#
# :class:`~anndata.AnnData` stores a data matrix :attr:`X` together with annotations
# of observations :attr:`obs` (:attr:`obsm`, :attr:`obsp`),
# variables :attr:`var` (:attr:`varm`, :attr:`varp`),
# and unstructured annotations :attr:`uns`.
#
# An :class:`~anndata.AnnData` object `adata` can be sliced like a
# :class:`~pandas.DataFrame`,
# for instance `adata_subset = adata[:, list_of_variable_names]`.
# :class:`~anndata.AnnData`’s basic structure is similar to R’s ExpressionSet
# ...

# %%
#| echo: false
#| output: asis
show_doc(create_iso_adata)
# Out:
# ---
#
# [source](https://github.com/cobioda/allos/blob/main/allos/switch_search.py#L720){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_iso_adata
#
# >      create_iso_adata (path:str)
#
# *Creates an AnnData object containing isoform counts from a Sicelore output file.
#
# Parameters:
# - path (str): Path to the input file, which is expected to be tab-separated and contain:
#     - `transcriptId`: Transcript identifiers.
#     - `geneId`: Gene identifiers.
#     - Transcript counts for individual barcodes (cells) as additional columns.
#
# Returns:
# - adata_iso (AnnData): An AnnData object with isoform counts.*
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | path | str | Path to a tab-separated file, typically the Sicelore output with transcript counts. |
