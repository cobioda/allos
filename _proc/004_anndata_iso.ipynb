# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(AnnDataIso)
# Out:
# C:\Users\Anna\PycharmProjects\allos\.venv\Lib\site-packages\fastcore\docscrape.py:230: UserWarning: Unknown section See Also
#   else: warn(msg)
# ---
#
# [source](https://github.com/cobioda/allos/blob/main/allos/anndata_iso.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### AnnDataIso
#
# >      AnnDataIso (anndata:anndata._core.anndata.AnnData,
# >                  cell_types:pandas.core.frame.DataFrame, palette='ghibli')
#
# *An annotated data matrix.
#
# .. figure:: ../_static/img/anndata_schema.svg
#    :width: 260px
#    :align: right
#    :class: dark-light
#
# :class:`~anndata.AnnData` stores a data matrix :attr:`X` together with annotations
# of observations :attr:`obs` (:attr:`obsm`, :attr:`obsp`),
# variables :attr:`var` (:attr:`varm`, :attr:`varp`),
# and unstructured annotations :attr:`uns`.
#
# An :class:`~anndata.AnnData` object `adata` can be sliced like a
# :class:`~pandas.DataFrame`,
# ...
