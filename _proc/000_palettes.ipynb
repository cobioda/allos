# %% [raw]
# ---
# description: The module provides several palettes that are recomended to be used with
#   plotting functions offered by Allos.
# output-file: palettes.html
# title: Palettes
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Display the color palette
sns.palplot(synthwave)
plt.show()

# %%
sns.palplot(ghibli)
plt.show()
